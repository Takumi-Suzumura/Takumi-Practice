# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Takumi-Suzumura/Takumi-Practice/blob/master/15%E7%AB%A0.ipynb)

# %%
from random import shuffle

class Card:
  suits = ["spades", "hearts", "diamonds", "clubs"]
  
  values = [None, None,
           "2", "3", "4", "5", "6", "7", "8", "9", "10",
           "Jack", "Queen", "King", "Ace"]
  
  def __init__(self, v, s):
    """スートも値も整数値"""
    self.value = v
    self.suit = s
   
  def __Lt__(self, c2):
    if self.value < c2.value:
      return True
    if self.value == c2.value:
      if self.suit < c2.suit:
        return True
      else:
        return False
    return False
  
  def __gt__(self, c2):
    if self.value > c2.value:
      return True
    if self.value == c2.value:
      if self.suit > c2.suit:
        return True
      else:
        return False
    return False
  
  def __repr__(self):
    v = self.values[self.value] + " of " \
        + self.suits[self.suit]
    return v
  
  
  
class Deck:
  def __init__(self):
    self.cards = []
    for i in range(2, 15):
      for j in range(4):
         self.cards.append(Card(i, j))
    shuffle(self.cards)
      
  def rm_card(self):
     if len(self.cards) == 0:
      return
     return self.cards.pop()
    
    
    
class Player:
  def __init__(self, name):
    self.wins = 0
    self.card = None
    self.name = name
    
    
class Game:
  def __init__(self):
    name1 = input("プレーヤー1の名前　")
    name2 = input("プレーヤー2の名前　")
    self.deck = Deck()
    self.p1 = Player(name1)
    self.p2 = Player(name2)
    
  def wins(self, winner):
    w = "このラウンドは {} が勝ちました"
    w = w.format(winner)
    print(w)
    
  def draw(self, p1n, p1c, p2n, p2c):
    d = "{} は {}、{} は {} を引きました"
    d = d.format(p1n, p1c, p2n, p2c)
    print(d)
    
  def play_game(self):
    cards = self.deck.cards
    print("さあ、戦のはじまりですにゃ(｀・ω・´)")
    while len(cards) >= 2:
      m = "qキーで終了。それ以外のキーで開始:"
      response = input(m)
      if response == 'q':
        break
      p1c = self.deck.rm_card()
      p2c = self.deck.rm_card()
      p1n = self.p1.name
      p2n = self.p2.name
      self.draw(p1n, p1c, p2n, p2c)
      if p1c > p2c:
        self.p1.wins += 1
        self.wins(self.p1.name)
      else:
        self.p2.wins += 1
        self.wins(self.p2.name)
      
    win = self.winner(self.p1, self.p2)
    print("そこまで！ {} の勝ちですにゃ！".format(win))
    
  def winner(self, p1, p2):
    if p1.wins > p2.wins:
      return p1.name
    if p1.wins < p2.wins:
      return p2.name
    return "ひきわけっ！"
  
game = Game()
game.play_game()
# Out:
# プレーヤー1の名前　s
# プレーヤー2の名前　s
# さあ、戦のはじまりですにゃ(｀・ω・´)
# qキーで終了。それ以外のキーで開始:a
# s は 2 of clubs、s は 9 of diamonds を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:a
# s は Queen of diamonds、s は 10 of hearts を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:a
# s は Ace of diamonds、s は 5 of diamonds を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:
# qキーで終了。それ以外のキーで開始:
# s は 2 of diamonds、s は 7 of diamonds を引きました
# このラウンドは s が勝ちました
# s は 9 of spades、s は 6 of diamonds を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:
# qキーで終了。それ以外のキーで開始:a
# s は 5 of spades、s は 2 of hearts を引きました
# このラウンドは s が勝ちました
# s は Jack of hearts、s は Jack of diamonds を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:a
# s は 10 of clubs、s は 6 of spades を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:aaaa
# s は 8 of spades、s は 3 of hearts を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:d
# s は 3 of spades、s は Queen of spades を引きました
# このラウンドは s が勝ちました
# qキーで終了。それ以外のキーで開始:
# s は 5 of hearts、s は Queen of hearts を引きました
# このラウンドは s が勝ちました
# ...
